# %% [markdown]
# M02 excercise

# %%
#create a string
name = "Michael"
print("First three characters:", name[:3])
print("Next three characters:", name[4:6])

# %%
#create a list
namelist = ['michael', 'duncan', 'macfarlan']
namelist
print(namelist[0])
print(namelist[2])
# Out:
# ['michael', 'duncan', 'macfarlan']

# %%
#create a tuple
#these are efficient data structures
nametuple = ('mac', 'far', 'lan')
nametuple
type(nametuple)
nametuple.append('ahh')
#can't append a tuple
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-2ce39ceecd87> in <module>
#       4 nametuple
#       5 type(nametuple)
# ----> 6 nametuple.append('ahh')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
stringvalue = "Python"
set1 = {'is', 'so', 'cool'}
print(type(set1))
print(stringvalue in set1)
# Out:
# <class 'set'>
# False

# %%
dictionary = {1:"michael", 2:"duncan", 3:"macfarlan"}
dictionary[1]
# Out:
# 'michael'

# %%
dictionary.get(1)
# Out:
# 'michael'

# %%
dictionary.items()
# Out:
# dict_items([(1, 'michael'), (2, 'duncan'), (3, 'macfarlan')])

# %%
sent = "The quick brown fox jumped over the lazy dogs."
wordset = set(sent.lower().split())
words = sorted(wordset)
print(words)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-fe6a02f97c0e> in <module>
#       1 sent = "The quick brown fox jumped over the lazy dogs."
# ----> 2 wordset = set(sent.lower().split())
#       3 words = sorted(wordset)
#       4 print(words)
#
# TypeError: 'set' object is not callable

# %%
mac = 1
far = 2
lan = 3
print(f"mac {mac}, far {far}, lan {lan}")
# Out:
# mac 1, far 2, lan 3

# %%
value1 = 1.1
value2 = 2.9
value3 = int(value1 // value2)
type(value3)
# Out:
# int

# %% [markdown]
# ![image.png](attachment:48a4fac7-a18c-402c-b300-439ba6eec089.png)
